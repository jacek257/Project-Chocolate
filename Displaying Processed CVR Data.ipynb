# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
manual = np.loadtxt("/media/labrat/395Mount/Repos/Project-Chocolate/CO2.contrast")
automated = np.loadtxt('/media/labrat/395Mount/FSL_work/SH/SH_008_01102017 edits/CO2_contrast.txt')

# %%
print(len(manual))
plt.figure(figsize=(20,10))
plt.plot(manual)
plt.plot(automated, color='orange')
# Out:
# 340
