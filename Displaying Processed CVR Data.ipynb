# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
to_display = np.loadtxt("/media/labrat/395Mount/FSL_work/etco2.txt")

# %%
print(len(to_display))
plt.figure(figsize=(20,10))
plt.plot(to_display)
# Out:
# 340
