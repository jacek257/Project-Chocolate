# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
to_display = np.loadtxt("/media/labrat/395Mount/Repos/Project-Chocolate/CO2.contrast")
to_display2 = np.loadtxt("/media/labrat/395Mount/FSL_work/SH/SH_031_05052017_EDITS/CO2_contrast.txt")

# %%
print(len(to_display))
plt.figure(figsize=(20,10))
plt.plot(to_display)
plt.plot(to_display2)
# Out:
# 340
