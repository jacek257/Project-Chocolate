# %%
import analysis
import pandas as pd
import numpy as np
import scipy.signal as sg
import matplotlib
import matplotlib.pyplot as plt
from scipy.fftpack import fft, ifft

# %matplotlib inline

# %%
data = pd.read_csv('/media/labrat/395Mount/FSL_work/SH/SH_025_03282017_EDITS.txt', sep='\t|,', names=['Time', 'O2', 'CO2'],
                 usecols=['Time', 'O2', 'CO2'], index_col=False)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
filtered_data = analysis.fourier_filter(data.Time[1], data.CO2, 3,25)

# %%
# Time = sg.resample(data.Time, len(data.Time)*1000)
O2 = sg.resample(data.O2, len(data.O2)*1000)
CO2 = sg.resample(data.CO2, len(data.CO2)*1000)
plt.figure(figsize=(20,10))
plt.plot(O2)
plt.plot(CO2)
t_step = data.Time[len(data.Time)-1]/len(O2)

# %%
freq, power, disp = analysis.fourier_trans(t_step, O2)
plt.figure(figsize=(20,10))
plt.plot(power)
# Out:
# /usr/lib/python3/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,10))
plt.plot(ifft(analysis.filter(3,20, freq, power)), linewidth = 4)

resample_inverse = ifft(analysis.filter(3,20, freq, power))
np.savetxt("O2_resample.txt", sg.resample(resample_inverse, 640), delimiter='\n')
# Out:
# /usr/lib/python3/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,10))
plt.plot(filtered_data)
plt.plot(sg.savgol_filter(filtered_data,25,3))
plt.plot(np.loadtxt('/media/labrat/395Mount/FSL_work/SH/SH_025_03282017_EDITS/CO2_contrast.txt'))
# Out:
# /usr/lib/python3/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/scipy/signal/_savitzky_golay.py:330: ComplexWarning: Casting complex values to real discards the imaginary part
#   x = x.astype(np.float64)
