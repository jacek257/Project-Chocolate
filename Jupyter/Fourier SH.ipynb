# %%
import analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.fftpack import fft, ifft

# %matplotlib inline

# %%
data = pd.read_csv('./SH_001_12132016.txt', sep=',', names=['Time', 'O2', 'CO2'],
                 usecols=['Time', 'O2', 'CO2'], index_col=False)

# %%
filtered_data = analysis.fourier_filter(data.Time[1], data.O2)

# %%
plt.figure(figsize=(20,10))
plt.plot(data.Time, data.O2)
plt.plot(data.Time, data.CO2)

# %%
freq, power, disp = analysis.fourier_trans(data.Time[1], data.O2)
plt.figure(figsize=(20,10))

# %%
plt.figure(figsize=(20,10))
plt.plot(ifft(analysis.filter(3,30, freq, power)), linewidth = 4)
# Out:
# /Users/borainbow/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,10))
plt.plot(filtered_data)
