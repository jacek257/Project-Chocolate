# %%
import os
import numpy as np

# %%
folders = ['/media/ke/8tb_part2/FSL_work/SH/SH_002_20161216_edits',
           '/media/ke/8tb_part2/FSL_work/SH/SH_003_20161216_edits',
           '/media/ke/8tb_part2/FSL_work/SH/SH_011_20170131_edits',
           '/media/ke/8tb_part2/FSL_work/SH/SH_020_20170303_edits',
           '/media/ke/8tb_part2/FSL_work/SH/SH_022_20170307_edits']

# %%
for folder in folders:
    f_O2_tmp = np.loadtxt(folder+'/f_O2_contrast.txt')
    print(len(f_O2_tmp))
    f_CO2_tmp = np.loadtxt(folder+'/f_CO2_contrast.txt')
    print(len(f_CO2_tmp))
    p_O2_tmp = np.loadtxt(folder+'/p_O2_contrast.txt')
    print(len(p_O2_tmp))
    p_CO2_tmp = np.loadtxt(folder+'/p_CO2_contrast.txt')
    print(len(p_CO2_tmp))
    t_O2_tmp = np.loadtxt(folder+'/t_O2_contrast.txt')
    print(len(t_O2_tmp))
    t_CO2_tmp = np.loadtxt(folder+'/t_CO2_contrast.txt')
    print(len(t_O2_tmp))

# %%
f_O2 = 0
f_CO2 = 0
p_O2 = 0
p_CO2 = 0
t_O2 = 0
t_CO2 = 0
for folder in folders:
    f_O2 += np.loadtxt(folder+'/f_O2_contrast.txt')
    f_CO2 += np.loadtxt(folder+'/f_CO2_contrast.txt')
    p_O2 += np.loadtxt(folder+'/p_O2_contrast.txt')
    p_CO2 += np.loadtxt(folder+'/p_CO2_contrast.txt')
    t_O2 += np.loadtxt(folder+'/t_O2_contrast.txt')
    t_CO2 += np.loadtxt(folder+'/t_CO2_contrast.txt')

f_O2 /= 5
f_CO2 /= 5
p_O2 /= 5
p_CO2 /= 5
t_O2 /= 5
t_CO2 /= 5

print(f_O2)
print(f_CO2)
print(p_O2)
print(p_CO2)
print(t_O2)
print(t_CO2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/f_O2_contrast.txt', f_O2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/f_CO2_contrast.txt', f_CO2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/p_O2_contrast.txt', p_O2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/p_CO2_contrast.txt', p_CO2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/t_O2_contrast.txt', t_O2)
np.savetxt('/media/ke/8tb_part2/FSL_work/SH/Atlas/t_CO2_contrast.txt', t_CO2)
# Out:
# [20.0106317  19.87618912 19.82881263 19.84382231 19.89653822 19.96228042
#  19.98891558 19.95095165 19.90072007 19.83882961 19.84113713 19.8334944
#  19.81822791 19.81934465 19.8553266  19.91342181 19.9384346  19.91197153
#  19.87821127 19.89328982 19.95399219 20.00435457 19.97674577 19.87483182
#  19.75756968 19.75346401 19.96661157 20.52511872 21.48693849 22.84959013
#  24.58431234 26.6971134  29.07832249 31.86975431 35.08788089 38.78188542
#  42.94484541 47.52620111 52.25825638 56.77629598 60.84218077 64.33212331
#  67.09466355 69.25154133 70.8307626  71.9479088  72.73289839 73.34096642
#  73.81925141 74.14360896 74.34144458 74.48189994 74.5747014  74.67619799
#  74.85137552 75.07207306 75.29249704 75.49039725 75.66601263 75.7654705
#  75.78446749 75.7688721  75.72198291 75.75899097 75.92434161 76.19906916
#  76.48891577 76.72653273 76.90134194 77.12458844 77.58724913 78.24017747
#  78.86380243 78.96428156 78.08829431 76.12782586 73.4310655  70.43483324
# ...
