# %%
import os
import fnmatch

# %%
path = '/media/ke/8tb_part2/FSL_work/SH_info/'

parent, sub_dirs, files = next(os.walk(path))
for direct in sub_dirs:
    if fnmatch.fnmatch(direct, 'HV*'):
        path = parent+direct
        current, sub_dir, files = next(os.walk(path))
        for dirs in sub_dir:
            for file in os.listdir(path+'/'+dirs):
                if file[:2] == 'HV':
                    print(file)
                    os.rename(path+'/'+dirs+'/'+file, path+'/'+dirs+'/SH'+file[2:])
                    print(file)
                    print()
                else:
                    print(file)
        
        print()
# Out:
# HV002_AXIAL_FSPGR_MIN_20161216090218.json
# HV002_AXIAL_FSPGR_MIN_20161216090218.nii
# HV002_AXIAL_CUBE_T2_MIP_20161216090218.json
# HV002_AXIAL_CUBE_T2_MIP_20161216090218.nii
# HV002_Calibration_20161216090218.nii
# HV002_Calibration_20161216090218.json
# HV002_AXIAL_CUBE_FLAIR_RECON_AVG_20161216090218.json
# HV002_AXIAL_CUBE_FLAIR_RECON_AVG_20161216090218.nii
# HV002_COR_FSPGR_AVG_20161216090218.nii
# HV002_COR_FSPGR_AVG_20161216090218.json
# HV002_Sag_CUBE_FLAIR_20161216090218.json
# HV002_Sag_CUBE_FLAIR_20161216090218.nii
# HV002_Cerebral_Blood_Flow_20161216090218.nii
# HV002_Cerebral_Blood_Flow_20161216090218.json
# HV002_AX_CUBE_T2_AVG_20161216090218.nii
# HV002_AX_CUBE_T2_AVG_20161216090218.json
# HV002_Ax_SWAN_20161216090218.json
# HV002_Ax_SWAN_20161216090218.nii
# HV002_3D_ASL_(non-contrast)_20161216090218a.json
# HV002_3D_ASL_(non-contrast)_20161216090218.nii
# HV002_3D_ASL_(non-contrast)_20161216090218a.nii
# HV002_3D_ASL_(non-contrast)_20161216090218.json
# ...
