# %%
import analysis
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal as sg

# %matplotlib inline

# %%
data_path = '/media/labrat/395Mount/Review/SH/SH_042_05232017_EDITS.txt'

# %%
meants_path = '/media/labrat/395Mount/FSL_work/SH031/BOLD/meants.txt'

# %%
data = pd.read_csv(data_path, sep='\t|,', names=['Time', 'O2', 'CO2'],
                 usecols=['Time', 'O2', 'CO2'], index_col=False)[['Time', 'O2', 'CO2']]
filtered_O2 = analysis.fourier_filter(data.Time[1], data.O2, 3,25)
filtered_CO2 = analysis.fourier_filter(data.Time[1], data.CO2, 3,25)
# Out:
# /home/labrat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
# meants = np.loadtxt(meants_path,delimiter='\n')
# print(len(meants))

# %%
plt.figure(figsize=(20,10))
plt.plot(filtered_O2)
plt.plot(filtered_CO2)
plt.plot(np.loadtxt('/media/labrat/395Mount/Review/SH/SH_042_05232017_EDITS/CO2_contrast.txt'))

plt.show()

# %%
np.savetxt("/media/labrat/395Mount/FSL_work/Pass/O2.contrast", filtered_O2, delimiter='\n')

np.savetxt("/media/labrat/395Mount/FSL_work/Pass/CO2.contrast", filtered_CO2, delimiter='\n')

# %%
print(filtered_CO2)
# Out:
# [17.97994251 17.85086959 17.95153035 18.32558726 18.95302326 19.74838753
#  20.57511816 21.27357257 21.69696755 21.74722197 21.40227322 20.72796721
#  19.87081469 19.03208496 18.42794702 18.24370769 18.59185691 19.48319612
#  20.81784065 22.39885491 23.96655279 25.24709157 26.00586191 26.09501155
#  25.48549731 24.27711842 22.68439498 21.00098337 19.54955092 18.62679231
#  18.45401385 19.14233479 20.67840178 22.93229725 25.68495651 28.66880216
#  31.61316708 34.28577329 36.52301511 38.24463627 39.45189489 40.2116842
#  40.63160774 40.83222123 40.92240277 40.98229698 41.05596545 41.15338152
#  41.25933778 41.34563868 41.38282689 41.34855076 41.2311891  41.02903091
#  40.74667272 40.39097377 39.96874247 39.48740712 38.95856165 38.40291104
#  37.85421841 37.35970146 36.97505173 36.75371535 36.73191063 36.91256558
#  37.25242721 37.65664663 37.98403773 38.06409522 37.72416331 36.82247927
#  35.28083098 33.10980838 30.42038892 27.41783404 24.37720169 21.60353555
# ...
