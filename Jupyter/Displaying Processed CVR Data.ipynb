# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
to_display = np.loadtxt("../SH/SH_006_12212016 edits/O2_contrast.txt")

# %%
plt.figure(figsize=(20,10))
plt.plot(to_display)
