# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
manual = np.loadtxt("/media/labrat/395Mount/Repos/Project-Chocolate/CO2.contrast")
automated = np.loadtxt('/media/labrat/395Mount/Review/SH/SH_031_05052017_EDITS/CO2_contrast.txt')

# %%
print(len(to_display))
plt.figure(figsize=(20,10))
plt.plot(manual)
plt.plot(automated, color='orange')
# Out:
# 340
