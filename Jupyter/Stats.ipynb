# %%
import fnmatch
import os
import pandas as pd

# %%
path = '/media/ke/8tb_part2/FSL_work/feat/no_b_SH035.feat/'
O2 = path+'fq_O2/'
CO2 = path+'fq_CO2/'

# %%
path_txt = [file for file in os.listdir(path) if fnmatch.fnmatch(file, 'cluster*d.txt')]
for file in path_txt:
    print(file)
print()
O2_txt = [file for file in os.listdir(O2) if fnmatch.fnmatch(file, 'r*.txt')]
for file in O2_txt:
    print(file)
print()
CO2_txt = [file for file in os.listdir(CO2) if fnmatch.fnmatch(file, 'r*.txt')]
for file in CO2_txt:
    print(file)
print()
# Out:
# cluster_zstat1_std.txt
# cluster_zstat2_std.txt
#
# report.txt
#
# report.txt

# %%
cz1 = pd.read_csv(path+path_txt[0], sep='\t', usecols=['-log10(P)', 'Z-MAX', 'COPE-MEAN'])
cz1
# Out:
#    -log10(P)  Z-MAX  COPE-MEAN
# 0        110   8.19       1.57

# %%
cz2 = pd.read_csv(path+path_txt[1], sep='\t', usecols=['-log10(P)', 'COPE-MEAN'])
cz2
# Out:
#    -log10(P)  COPE-MEAN
# 0        116       9.44

# %%
r1 = pd.read_csv(O2+O2_txt[0], sep='\t| ', header=None, usecols=[5], engine='python')
r1 = r1.rename(columns={5 : 'mean'})
r1
# Out:
#     mean
# 0  1.675

# %%
r2 = pd.read_csv(CO2+CO2_txt[0], sep='\t| ', header=None, usecols=[5], engine='python')
r2 = r2.rename(columns={5 : 'mean'})
r2
# Out:
#     mean
# 0  1.911

# %%
dc = {'ID' : ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
      'type' : ['f', 'p', 't', 'f', 'p', 't', 'f', 'p', 't'],
      'score' : [0.7, 0.6, 0.8, 0.7, 0.6, 0.8, 0.7, 0.6, 0.8]}
df = pd.DataFrame(dc)
df
# Out:
#   ID type  score
# 0  A    f    0.7
# 1  A    p    0.6
# 2  A    t    0.8
# 3  B    f    0.7
# 4  B    p    0.6
# 5  B    t    0.8
# 6  C    f    0.7
# 7  C    p    0.6
# 8  C    t    0.8

# %%
dc2 = {'ID' : ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
      'type' : ['f', 'p', 't', 'f', 'p', 't', 'f', 'p', 't'],
      'score' : [0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.3, 0.3, 0.3]}
df2 = pd.DataFrame(dc2)
df2
# Out:
#   ID type  score
# 0  A    f    0.1
# 1  A    p    0.1
# 2  A    t    0.1
# 3  B    f    0.2
# 4  B    p    0.2
# 5  B    t    0.2
# 6  C    f    0.3
# 7  C    p    0.3
# 8  C    t    0.3

# %%
merged = df.merge(df2, on=['ID', 'type'], suffixes=('_O2', '_CO2'),)
merged
# Out:
#   ID type  score_O2  score_CO2
# 0  A    f       0.7        0.1
# 1  A    p       0.6        0.1
# 2  A    t       0.8        0.1
# 3  B    f       0.7        0.2
# 4  B    p       0.6        0.2
# 5  B    t       0.8        0.2
# 6  C    f       0.7        0.3
# 7  C    p       0.6        0.3
# 8  C    t       0.8        0.3

# %%
merged2 = df.merge(df2, left_on=['ID', 'type'], right_on=['ID', 'type'])
merged2
# Out:
#   ID type  score  score2
# 0  A    f    0.7     0.1
# 1  A    p    0.6     0.1
# 2  A    t    0.8     0.1
# 3  B    f    0.7     0.2
# 4  B    p    0.6     0.2
# 5  B    t    0.8     0.2
# 6  C    f    0.7     0.3
# 7  C    p    0.6     0.3
# 8  C    t    0.8     0.3

# %%
empty = pd.DataFrame()
empty
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
row1 = df.loc[0]
row1
# Out:
# ID         A
# type       f
# score    0.7
# Name: 0, dtype: object

# %%
rowt = df.loc[0:1]
rowt
# Out:
#   ID type  score
# 0  A    f    0.7
# 1  A    p    0.6

# %%
empty = empty.append(rowt)
empty
# Out:
#   ID type  score
# 0  A    f    0.7
# 1  A    p    0.6

# %%
row2 = df.loc[2:3]
row2
# Out:
#   ID type  score
# 2  A    t    0.8
# 3  B    f    0.7

# %%
empty = empty.append(row2)
empty
# Out:
#   ID type  score
# 0  A    f    0.7
# 1  A    p    0.6
# 2  A    t    0.8
# 3  B    f    0.7

# %%
empty = empty.append(rowt)
empty.reset_index(drop=True)
# Out:
#    ID type  score
# 0   A    f    0.7
# 1   A    p    0.6
# 2   A    t    0.8
# 3   B    f    0.7
# 4   A    f    0.7
# 5   A    p    0.6
# 6   A    f    0.7
# 7   A    p    0.6
# 8   A    f    0.7
# 9   A    p    0.6
# 10  A    f    0.7
# 11  A    p    0.6
# 12  A    f    0.7
# 13  A    p    0.6
# 14  A    f    0.7
# 15  A    p    0.6
